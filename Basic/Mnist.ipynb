# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot as plt

# Tải dữ liệu MNIST và chia thành tập huấn luyện và tập kiểm tra
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Chuẩn hóa dữ liệu và chuyển đổi nhãn thành one-hot encoding
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Xây dựng mô hình
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))  # Lớp Flatten
model.add(Dense(128, activation='relu'))   # Lớp ẩn với hàm kích hoạt ReLU
model.add(Dense(10, activation='softmax')) # Lớp đầu ra với hàm kích hoạt softmax
# Biên dịch mô hình
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình trên tập huấn luyện
model.fit(train_images, train_labels, epochs=5, batch_size=64)

# Đánh giá mô hình trên tập kiểm tra
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.3028 - accuracy: 0.9151
# Epoch 2/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.1350 - accuracy: 0.9613
# Epoch 3/5
# 938/938 [==============================] - 6s 7ms/step - loss: 0.0936 - accuracy: 0.9724
# Epoch 4/5
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0701 - accuracy: 0.9792
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0937 - accuracy: 0.9722
# Test accuracy: 0.9721999764442444

# %%
a= model.predict(test_images)
# for i in range(0,1000):
#     model.predict(test_images[i].reshape(1,28,28))
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
print(np.argmax(a[1]))
# Out:
# 2

# %%
# Dự đoán trên một mẫu dữ liệu cụ thể
for i in range(100):
    sample_index = i
    sample_image = test_images[sample_index]
    sample_label = np.argmax(test_labels[sample_index])

    prediction = model.predict(np.expand_dims(sample_image, axis=0))
    predicted_label = np.argmax(prediction)
    print(i)
    print(f'Ground Truth Label: {sample_label}')
    print(f'Predicted Label: {predicted_label}')
    plt.imshow(test_images[sample_index])
    plt.show()
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 0
# Ground Truth Label: 7
# Predicted Label: 7
# 1/1 [==============================] - 0s 30ms/step
# 1
# Ground Truth Label: 2
# Predicted Label: 2
# 1/1 [==============================] - 0s 32ms/step
# 2
# Ground Truth Label: 1
# Predicted Label: 1
# 1/1 [==============================] - 0s 28ms/step
# 3
# Ground Truth Label: 0
# Predicted Label: 0
# 1/1 [==============================] - 0s 23ms/step
# 4
# Ground Truth Label: 4
# Predicted Label: 4
# 1/1 [==============================] - 0s 50ms/step
# 5
# Ground Truth Label: 1
# Predicted Label: 1
# 1/1 [==============================] - 0s 22ms/step
# 6
# Ground Truth Label: 4
# Predicted Label: 4
# 1/1 [==============================] - 0s 36ms/step
# 7
# Ground Truth Label: 9
# Predicted Label: 9
# 1/1 [==============================] - 0s 24ms/step
# 8
# Ground Truth Label: 5
# Predicted Label: 5
# 1/1 [==============================] - 0s 19ms/step
# 9
# ...
