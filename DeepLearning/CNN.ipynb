# %%
#pip install torch torchvision

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Tải dữ liệu MNIST và chia thành tập huấn luyện và tập kiểm tra
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Chuẩn hóa dữ liệu và chuyển dạng nhãn thành one-hot encoding
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))
train_images, test_images = train_images / 255.0, test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# Xây dựng mô hình CNN
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
# model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# Biên dịch mô hình
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
model.fit(train_images, train_labels, epochs=5, batch_size=64)

# Đánh giá mô hình trên tập kiểm tra
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Độ chính xác trên tập kiểm tra:", test_acc)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 20s 20ms/step - loss: 0.2073 - accuracy: 0.9409
# Epoch 2/5
# 938/938 [==============================] - 19s 20ms/step - loss: 0.0761 - accuracy: 0.9780
# Epoch 3/5
# 938/938 [==============================] - 17s 18ms/step - loss: 0.0550 - accuracy: 0.9840
# Epoch 4/5
# 938/938 [==============================] - 18s 19ms/step - loss: 0.0423 - accuracy: 0.9876
# Epoch 5/5
# 938/938 [==============================] - 18s 20ms/step - loss: 0.0352 - accuracy: 0.9894
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0663 - accuracy: 0.9798
# Độ chính xác trên tập kiểm tra: 0.9797999858856201

# %%
import numpy as np
for i in range(100):
    predict = model.predict((test_images[i]).reshape(1,28,28))
    print(np.argmax(predict))

    print(np.argmax(test_labels[i]))
# Out:
# 1/1 [==============================] - 0s 74ms/step
# 7
# 7
# 1/1 [==============================] - 0s 27ms/step
# 2
# 2
# 1/1 [==============================] - 0s 33ms/step
# 1
# 1
# 1/1 [==============================] - 0s 33ms/step
# 0
# 0
# 1/1 [==============================] - 0s 29ms/step
# 4
# 4
# 1/1 [==============================] - 0s 31ms/step
# 1
# 1
# 1/1 [==============================] - 0s 29ms/step
# 4
# 4
# 1/1 [==============================] - 0s 27ms/step
# 9
# 9
# 1/1 [==============================] - 0s 41ms/step
# 6
# 5
# 1/1 [==============================] - 0s 31ms/step
# 9
# 9
# 1/1 [==============================] - 0s 33ms/step
# 0
# 0
# 1/1 [==============================] - 0s 28ms/step
# 6
# 6
# 1/1 [==============================] - 0s 38ms/step
# 9
# 9
# 1/1 [==============================] - 0s 35ms/step
# 0
# 0
# 1/1 [==============================] - 0s 32ms/step
# 1
# 1
# 1/1 [==============================] - 0s 43ms/step
# 5
# 5
# 1/1 [==============================] - 0s 33ms/step
# 9
# 9
# 1/1 [==============================] - 0s 35ms/step
# 7
# 7
# 1/1 [==============================] - 0s 37ms/step
# 8
# 3
# 1/1 [==============================] - 0s 32ms/step
# 4
# 4
# 1/1 [==============================] - 0s 22ms/step
# 9
# 9
# 1/1 [==============================] - 0s 26ms/step
# 6
# 6
# 1/1 [==============================] - 0s 27ms/step
# 6
# 6
# 1/1 [==============================] - 0s 14ms/step
# 5
# 5
# 1/1 [==============================] - 0s 23ms/step
# 4
# 4
# 1/1 [==============================] - 0s 19ms/step
# 0
# 0
# 1/1 [==============================] - 0s 22ms/step
# 7
# 7
# 1/1 [==============================] - 0s 21ms/step
# 4
# 4
# 1/1 [==============================] - 0s 20ms/step
# 0
# 0
# 1/1 [==============================] - 0s 15ms/step
# 1
# 1
# 1/1 [==============================] - 0s 24ms/step
# 3
# 3
# 1/1 [==============================] - 0s 9ms/step
# 1
# 1
# 1/1 [==============================] - 0s 24ms/step
# 3
# 3
# 1/1 [==============================] - 0s 23ms/step
# 4
# 4
# 1/1 [==============================] - 0s 16ms/step
# 7
# 7
# 1/1 [==============================] - 0s 25ms/step
# 2
# 2
# 1/1 [==============================] - 0s 21ms/step
# 7
# 7
# 1/1 [==============================] - 0s 17ms/step
# 1
# 1
# 1/1 [==============================] - 0s 23ms/step
# 2
# 2
# 1/1 [==============================] - 0s 26ms/step
# 1
# 1
# 1/1 [==============================] - 0s 25ms/step
# 1
# 1
# 1/1 [==============================] - 0s 26ms/step
# 7
# 7
# 1/1 [==============================] - 0s 21ms/step
# 4
# 4
# 1/1 [==============================] - 0s 21ms/step
# 2
# 2
# 1/1 [==============================] - 0s 19ms/step
# 3
# 3
# 1/1 [==============================] - 0s 25ms/step
# 5
# 5
# 1/1 [==============================] - 0s 16ms/step
# 1
# 1
# 1/1 [==============================] - 0s 26ms/step
# 2
# 2
# 1/1 [==============================] - 0s 23ms/step
# 4
# 4
# 1/1 [==============================] - 0s 24ms/step
# 4
# 4
# 1/1 [==============================] - 0s 27ms/step
# 6
# 6
# 1/1 [==============================] - 0s 25ms/step
# 3
# 3
# 1/1 [==============================] - 0s 24ms/step
# 5
# 5
# 1/1 [==============================] - 0s 22ms/step
# 5
# 5
# 1/1 [==============================] - 0s 24ms/step
# 6
# 6
# 1/1 [==============================] - 0s 17ms/step
# 0
# 0
# 1/1 [==============================] - 0s 16ms/step
# 4
# 4
# 1/1 [==============================] - 0s 25ms/step
# 1
# 1
# 1/1 [==============================] - 0s 18ms/step
# 9
# 9
# 1/1 [==============================] - 0s 18ms/step
# 5
# 5
# 1/1 [==============================] - 0s 25ms/step
# 7
# 7
# 1/1 [==============================] - 0s 17ms/step
# 8
# 8
# 1/1 [==============================] - 0s 23ms/step
# 5
# 9
# 1/1 [==============================] - 0s 15ms/step
# 3
# 3
# 1/1 [==============================] - 0s 27ms/step
# 7
# 7
# 1/1 [==============================] - 0s 19ms/step
# 4
# 4
# 1/1 [==============================] - 0s 17ms/step
# 6
# 6
# 1/1 [==============================] - 0s 18ms/step
# 4
# 4
# 1/1 [==============================] - 0s 18ms/step
# 3
# 3
# 1/1 [==============================] - 0s 26ms/step
# 0
# 0
# 1/1 [==============================] - 0s 22ms/step
# 7
# 7
# 1/1 [==============================] - 0s 17ms/step
# 0
# 0
# 1/1 [==============================] - 0s 25ms/step
# 2
# 2
# 1/1 [==============================] - 0s 16ms/step
# 9
# 9
# 1/1 [==============================] - 0s 24ms/step
# 1
# 1
# 1/1 [==============================] - 0s 25ms/step
# 7
# 7
# 1/1 [==============================] - 0s 18ms/step
# 3
# 3
# 1/1 [==============================] - 0s 31ms/step
# 2
# 2
# 1/1 [==============================] - 0s 18ms/step
# 9
# 9
# 1/1 [==============================] - 0s 17ms/step
# 7
# 7
# 1/1 [==============================] - 0s 15ms/step
# 7
# 7
# 1/1 [==============================] - 0s 20ms/step
# 6
# 6
# 1/1 [==============================] - 0s 16ms/step
# 2
# 2
# 1/1 [==============================] - 0s 18ms/step
# 7
# 7
# 1/1 [==============================] - 0s 26ms/step
# 8
# 8
# 1/1 [==============================] - 0s 22ms/step
# 4
# 4
# 1/1 [==============================] - 0s 26ms/step
# 7
# 7
# 1/1 [==============================] - 0s 32ms/step
# 3
# 3
# 1/1 [==============================] - 0s 18ms/step
# 6
# 6
# 1/1 [==============================] - 0s 23ms/step
# 1
# 1
# 1/1 [==============================] - 0s 10ms/step
# 3
# 3
# 1/1 [==============================] - 0s 28ms/step
# 6
# 6
# 1/1 [==============================] - 0s 18ms/step
# 9
# 9
# 1/1 [==============================] - 0s 31ms/step
# 3
# 3
# 1/1 [==============================] - 0s 17ms/step
# 1
# 1
# 1/1 [==============================] - 0s 20ms/step
# 4
# 4
# 1/1 [==============================] - 0s 23ms/step
# 1
# 1
# 1/1 [==============================] - 0s 25ms/step
# 7
# 7
# 1/1 [==============================] - 0s 27ms/step
# 6
# 6
# 1/1 [==============================] - 0s 18ms/step
# 9
# 9
